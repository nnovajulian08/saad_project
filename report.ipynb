# %% [markdown]
# # Open Shop and Job Shop

# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## MIP Model

# %% [markdown]
# ## CP Model

# %% [markdown]
# ## Analysis of Tests and Results

# %% [markdown]
# ## Conclusions
